# %% [markdown]
# # Developer Friction Analysis

# %%
import json
from pathlib import Path
for p in Path('../data/datasets').glob('*.json'):
    d = json.loads(p.read_text())
    print(d['dataset_id'], d['ci_duration_min_avg'])
